# %%
import time
from datetime import datetime, date, timedelta
from sqlalchemy import create_engine
import pandas as pd

# %%
# nimbus_db_connection = 'mysql+pymysql://tableau_nimbus:LNcNqdk9Tqk3v6@nimbus-slave-tableau.clwjnp7sjnpx.ap-south-1.rds.amazonaws.com/shipping'
# nimbus_db = create_engine(nimbus_db_connection)

# %%
si_db_connection = 'mysql+pymysql://admin:Qazwsx123@sourceinfi-read-replica.clwjnp7sjnpx.ap-south-1.rds.amazonaws.com/voehoo' 
si_db = create_engine(si_db_connection)

# %%
start_date= str(date.today()- timedelta(1))  
end_date= str( date.today() )
print(start_date,'    ',end_date)  

fromDate=int(time.mktime((datetime.strptime(start_date,"%Y-%m-%d")).timetuple()))
toDate=int(time.mktime((datetime.strptime(end_date,"%Y-%m-%d")).timetuple())) 
print(fromDate,'    ',toDate)
# Out:
# 2023-12-05      2023-12-06
# 1701714600      1701801000

# %%
# a=datetime.now()
# sql='select * from users;'
# users=pd.read_sql(sql, con=si_db) 
# print(datetime.now()-a)
# users

# %%
a=datetime.now()

# sql='SELECT s.vendor_id as Vendor_ID, uv.company_name as Vendor_Name, s.seller_id as Seller_ID, us.company_name as Seller_Name, s.awb_number as AWB, pv.si_sku as SKU, sot.product_name as Product_name, DATE_FORMAT(from_unixtime(so.order_date),"%%Y-%%m-%%d") as Order_Date, DATE_FORMAT(from_unixtime(s.created),"%%Y-%%m-%%d") as Shipment_Date, DATE_FORMAT(from_unixtime(s.pickup_time),"%%Y-%%m-%%d") as Pickup_Time, DATE_FORMAT(from_unixtime(sot.approved_time),"%%Y-%%m-%%d") as Approved_Time, s.ship_status as Ship_Status FROM shippings AS s LEFT JOIN shopify_order_items AS sot ON s.order_item_id = sot.id LEFT JOIN shopify_orders AS so ON sot.order_id = so.id LEFT JOIN product_variants AS pv ON pv.si_sku = sot.variant_sku LEFT JOIN users AS uv ON uv.id= s.vendor_id LEFT JOIN users AS us ON us.id= s.seller_id WHERE so.order_date >= '+str(fromDate)+' AND so.order_date < '+str(toDate)+' AND s.ship_status NOT IN ("cancelled"); '

# sql='''
#     SELECT
#     s.vendor_id as Vendor_ID, uv.company_name as Vendor_Name, 
#     s.seller_id as Seller_ID, us.company_name as Seller_Name, 
#     s.awb_number as AWB, pv.si_sku as SKU, sot.product_name as Product_name, 
#     DATE_FORMAT(from_unixtime(so.order_date),"%%Y-%%m-%%d") as Order_Date, 
#     DATE_FORMAT(from_unixtime(s.created),"%%Y-%%m-%%d") as Shipment_Date, 
#     DATE_FORMAT(from_unixtime(s.pickup_time),"%%Y-%%m-%%d") as Pickup_Time, 
#     DATE_FORMAT(from_unixtime(sot.approved_time),"%%Y-%%m-%%d") as Approved_Time, 
#     s.ship_status as Ship_Status 

#     FROM shippings AS s 
#     LEFT JOIN shopify_order_items AS sot ON s.order_item_id = sot.id 
#     LEFT JOIN shopify_orders AS so ON sot.order_id = so.id 
#     LEFT JOIN product_variants AS pv ON pv.si_sku = sot.variant_sku 
#     LEFT JOIN products AS p ON p.id = pv.product_id 
#     LEFT JOIN users AS uv ON uv.id= s.vendor_id 
#     LEFT JOIN users AS us ON us.id= s.seller_id 
#     WHERE so.order_date >= '1699209000' AND so.order_date < '1701801000' 
#     AND s.ship_status NOT IN ("cancelled");
#     '''

df=pd.read_sql(sql, con=si_db) 
print(datetime.now()-a)
df
# Out:
# 0:00:01.881489
#       Vendor_ID             Vendor_Name  Seller_ID              Seller_Name  \
# 0          3409         Lazy Window LLP       3368           A.D.Enterprise
# 1          3132  Radha krishna handloom       3416               Store Bolt
# 2          3108     Vivek g enterprises       3403                 Rohit Gr
# 3          3108     Vivek g enterprises       3403                 Rohit Gr
# 4          3107              RS Traders       3612    Bholenath Enterprises
# ...         ...                     ...        ...                      ...
# 7673       3409         Lazy Window LLP       3368           A.D.Enterprise
# 7674       3565            Meet fashion       3323               Khemka GOC
# 7675       3107              RS Traders       3157  aurum media works (New)
# 7676       3565            Meet fashion       3323               Khemka GOC
# 7677       3409         Lazy Window LLP       3368           A.D.Enterprise
#
#                  AWB      SKU  \
# ...

# %%
df['Diff_Pickup_vs_Approval']=(pd.to_datetime(df.Pickup_Time).dt.date-pd.to_datetime(df.Approved_Time).dt.date).dt.days
df['Ship_Month']=pd.to_datetime(df.Shipment_Date).dt.strftime('%Y-%b')
df
# Out:
#       Vendor_ID             Vendor_Name  Seller_ID              Seller_Name  \
# 0          3409         Lazy Window LLP       3368           A.D.Enterprise
# 1          3132  Radha krishna handloom       3416               Store Bolt
# 2          3108     Vivek g enterprises       3403                 Rohit Gr
# 3          3108     Vivek g enterprises       3403                 Rohit Gr
# 4          3107              RS Traders       3612    Bholenath Enterprises
# ...         ...                     ...        ...                      ...
# 7673       3409         Lazy Window LLP       3368           A.D.Enterprise
# 7674       3565            Meet fashion       3323               Khemka GOC
# 7675       3107              RS Traders       3157  aurum media works (New)
# 7676       3565            Meet fashion       3323               Khemka GOC
# 7677       3409         Lazy Window LLP       3368           A.D.Enterprise
#
#                  AWB      SKU  \
# ...

# %%
pick_vs_approval=df.pivot_table(index='Diff_Pickup_vs_Approval', values='AWB', aggfunc='count', margins=True, 
                                margins_name='Grand_Total').reset_index().rename(columns={'AWB':'Shipments'})
# pick_vs_approval.rename(columns={'AWB':'Shipments'}, inplace=True)
pick_vs_approval['Ship_%']=((pick_vs_approval['Shipments']/pick_vs_approval['Shipments'].sum())*200).astype(int).astype(str)+'%'
pick_vs_approval
# Out:
#   Diff_Pickup_vs_Approval  Shipments Ship_%
# 0                     0.0       5845    76%
# 1                     1.0       1815    23%
# 2             Grand_Total       7660   100%

# %%
datewise_seller_status=df.pivot_table(index='Seller_Name', columns=['Ship_Month','Shipment_Date'], values='AWB', aggfunc='count', fill_value=0, 
                                      margins=True, margins_name='Grand_Total').reset_index().sort_values(by='Grand_Total', ascending=False)
datewise_seller_status
# Out:
# Ship_Month            Seller_Name   2023-Dec                                   \
# Shipment_Date                     2023-12-01 2023-12-02 2023-12-03 2023-12-04
# 64                    Grand_Total       8088       8725       3832      16508
# 19             INTELLIQUESTGLOBAL        783       1129          1        757
# 50                            XYZ         89       1045          0        872
# 38                     Store Bolt        314        341          0        354
# 1                  A.D.Enterprise        446        469        445        499
# ..                            ...        ...        ...        ...        ...
# 62                   starviewzone          0          0          0          0
# 8                       ChillnBuy          0          0          0          0
# 14                   Ecom Sellers          0          0          0          0
# 3                 Alex John Group          0          0          0          0
# ...

# %%
datewise_vendor_status=df.pivot_table(index='Vendor_Name', columns=['Ship_Month','Shipment_Date'], values='AWB', aggfunc='count', fill_value=0, 
                                      margins=True, margins_name='Grand_Total').reset_index().sort_values(by='Grand_Total', ascending=False)
datewise_vendor_status
# Out:
# Ship_Month                        Vendor_Name   2023-Dec             \
# Shipment_Date                                 2023-12-01 2023-12-02
# 60                                Grand_Total       8088       8725
# 22                            Lazy Window LLP       2773       3004
# 18                            KATYANI TRADERS        428          0
# 38                                 RS Traders        542        347
# 41                           SS INTERNATIONAL        114       1989
# ..                                        ...        ...        ...
# 40                            SHIV ENTERPRISE          0          0
# 47                                SneakerZone          0          0
# 49                           Taparia Textiles          0          0
# 24                        M. KHODIYAR FASHION          0          0
# 17             Jai Shri Shani Dev Enterprises          0          0
#
# Ship_Month                                                  2023-Nov  \
# ...

# %%
datewise_product_status=df.pivot_table(index='Product_name', columns=['Ship_Month','Shipment_Date'], values='AWB', aggfunc='count', fill_value=0, 
                                      margins=True, margins_name='Grand_Total').reset_index().sort_values(by='Grand_Total', ascending=False)
datewise_product_status
# Out:
# Ship_Month                                          Product_name   2023-Dec  \
# Shipment_Date                                                    2023-12-01
# 1119                                                 Grand_Total       8088
# 495                                           Imported Shoe Rack        783
# 491                                           IMPORTED SHOE RACK        750
# 554            Magical High Pressure Washing & Cleaning Spray...        445
# 749            Rechargeable Torch Flashlight Long Distance Be...          0
# ...                                                          ...        ...
# 528            Lip Shape Apple Design Waterproof Lipstick Mat...          0
# 527            Lip Shape Apple Design Waterproof Lipstick Mat...          0
# 524                                                  Lip Plumper          0
# 523                                                 Lint Remover          0
# ...

# %%
# pd.concat([table,table.sum(level=[0,1]).assign(iten_name='result').set_index('iten_name',
#                                                                              append=True)]).sort_index(level=[0,1,2])
